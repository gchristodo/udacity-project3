# %%
import logging
import pickle
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from settings import settings

from data import process_data
from model import (
    train_model,
    get_model_metrics,
    get_inference,
    get_slices,
    get_confusion_matrix,
)

# %%
logging.basicConfig(
    filename="pipeline.log",
    level=logging.INFO,
    filemode="a",
    format="%(name)s - %(levelname)s - %(message)s",
)

# %%
data = pd.read_csv(settings["data_path"])
target = settings["target_variable"]
cat_features = settings["cat_features"]
model_save_path = settings["model_path"]
model_pkl = settings["pkl_files"]["model"]
encoder_pkl = settings["pkl_files"]["encoder"]
labelizer_pkl = settings["pkl_files"]["labelizer"]
slices_save_path = settings["slices_save_path"]

# %%
train, test = train_test_split(
    data, test_size=0.20, random_state=42, stratify=data[target]
)

# %%
X_train, y_train, encoder, lb = process_data(
    train, categorical_features=cat_features, label=target, training=True
)
# Out:
# C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_test, y_test, encoder, lb = process_data(
    test,
    categorical_features=cat_features,
    label="salary",
    training=False,
    encoder=encoder,
    lb=lb,
)

# %%
if os.path.isfile(os.path.join(model_save_path, model_pkl)):
    # Load model
    model = pickle.load(open(os.path.join(model_save_path, model_pkl), "rb"))
    # Load encoder
    encoder = pickle.load(open(os.path.join(model_save_path, encoder_pkl), "rb"))
    # Load labalizer
    lb = pickle.load(open(os.path.join(model_save_path, labelizer_pkl), "rb"))
# If not, train and save a model.
else:
    model = train_model(X_train, y_train)
    # save model  to disk in ./model folder
    pickle.dump(model, open(os.path.join(model_save_path, model_pkl), "wb"))
    pickle.dump(encoder, open(os.path.join(model_save_path, encoder_pkl), "wb"))
    pickle.dump(lb, open(os.path.join(model_save_path, labelizer_pkl), "wb"))
    logging.info("Model saved to disk: %d", model_save_path)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not dict
# Call stack:
# BEST PARAMS:  {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3216195805.py", line 10, in <cell line: 1>
#     model = train_model(X_train, y_train)
#   File "C:\Users\gchri\Desktop\Pfizer\Udacity\Chapter_3\Project_3\udacity-project3\starter\ml\model.py", line 78, in train_model
#     logging.info("BEST PARAMS: %d", rf_clf.best_params_)
# Message: 'BEST PARAMS: %d'
# Arguments: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3216195805.py", line 15, in <cell line: 1>
#     logging.info("Model saved to disk: %d", model_save_path)
# Message: 'Model saved to disk: %d'
# Arguments: ('../model',)

# %%
# Getting the predictions
y_pred = get_inference(model, X_test)
# Evaluating the model
precision, recall, fbeta = get_model_metrics(y_test, y_pred)
logging.info("precision: %d, recall: %d, fbeta: %d", precision, recall, fbeta)
# Calculating confusion matrix
cm = get_confusion_matrix(y_test, y_pred)
logging.info("confusion matrix: %d", cm)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not numpy.ndarray
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\1802011892.py", line 8, in <cell line: 8>
#     logging.info("confusion matrix: %d", cm)
# Message: 'confusion matrix: %d'
# Arguments: (array([[4661,  284],
#        [ 560, 1008]], dtype=int64),)

# %%
precision
# Out:
# 0.7801857585139319

# %%
recall
# Out:
# 0.6428571428571429

# %%
fbeta
# Out:
# 0.7048951048951049

# %%
# Evaluating the slices of all categorical features
# and saving the results in a csv file and in pipeline log
for feature in cat_features:
    perf_df = get_slices(test, feature, y_test, y_pred)
    perf_df.to_csv(slices_save_path, mode="a", index=False)
    logging.info("Performance on slice %d", feature)
    logging.info(perf_df)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('workclass',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('education',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('marital-status',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('occupation',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('relationship',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('race',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('sex',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 929, in format
#     return fmt.format(record)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\logging\__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: %d format: a number is required, not str
# Call stack:
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\gchri\anaconda3\envs\udacity\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\gchri\AppData\Local\Temp\ipykernel_21700\3588240420.py", line 6, in <cell line: 3>
#     logging.info("Performance on slice %d", feature)
# Message: 'Performance on slice %d'
# Arguments: ('native-country',)

# %%
perf_df
# Out:
#                        feature   feature_value  n_samples  precision  \
# 0                United-States  native-country       5835   0.787724
# 1                     Thailand  native-country          7   1.000000
# 2                        China  native-country         14   0.750000
# 3                    Nicaragua  native-country         11   0.000000
# 4                       Mexico  native-country        111   0.500000
# 5                       Canada  native-country         28   0.250000
# 6                        South  native-country         12   1.000000
# 7                            ?  native-country        125   0.787879
# 8                        India  native-country         18   0.700000
# 9                        Italy  native-country         13   1.000000
# 10                    Portugal  native-country          7   1.000000
# 11                     Vietnam  native-country         15   1.000000
# 12                 Puerto-Rico  native-country         22   0.666667
# 13          Dominican-Republic  native-country         12   1.000000
# 14                 El-Salvador  native-country         21   1.000000
# 15                     Germany  native-country         28   0.800000
# 16                 Philippines  native-country         41   0.615385
# 17                     England  native-country         22   0.600000
# 18                  Yugoslavia  native-country          8   1.000000
# 19                      Poland  native-country         12   0.500000
# 20                     Jamaica  native-country         21   1.000000
# 21  Outlying-US(Guam-USVI-etc)  native-country          4   1.000000
# 22                    Scotland  native-country          4   1.000000
# 23                    Cambodia  native-country          3   1.000000
# 24                        Iran  native-country         12   0.250000
# 25                    Columbia  native-country         11   0.000000
# 26                       Haiti  native-country          8   1.000000
# 27                   Guatemala  native-country         21   1.000000
# 28                      Taiwan  native-country          7   0.750000
# 29                     Ecuador  native-country          3   1.000000
# 30                        Cuba  native-country         12   1.000000
# 31                      Greece  native-country          4   1.000000
# 32                       Japan  native-country         16   0.800000
# 33                      France  native-country          2   0.000000
# 34                     Hungary  native-country          2   0.500000
# 35                    Honduras  native-country          3   1.000000
# 36             Trinadad&Tobago  native-country          4   1.000000
# 37                        Peru  native-country          7   1.000000
# 38                        Hong  native-country          3   1.000000
# 39                     Ireland  native-country          2   1.000000
# 40                        Laos  native-country          2   1.000000
#
#       recall     fbeta
# 0   0.640777  0.706692
# 1   1.000000  1.000000
# 2   0.750000  0.750000
# 3   0.000000  0.000000
# 4   0.333333  0.400000
# 5   0.200000  0.222222
# 6   0.166667  0.285714
# 7   0.812500  0.800000
# 8   1.000000  0.823529
# 9   0.750000  0.857143
# 10  0.000000  0.000000
# 11  1.000000  1.000000
# 12  1.000000  0.800000
# 13  1.000000  1.000000
# 14  1.000000  1.000000
# 15  0.571429  0.666667
# 16  0.666667  0.640000
# 17  0.428571  0.500000
# 18  0.500000  0.666667
# 19  1.000000  0.666667
# 20  1.000000  1.000000
# 21  1.000000  1.000000
# 22  1.000000  1.000000
# 23  1.000000  1.000000
# 24  0.333333  0.285714
# 25  1.000000  0.000000
# 26  1.000000  1.000000
# 27  0.500000  0.666667
# 28  1.000000  0.857143
# 29  1.000000  1.000000
# 30  0.500000  0.666667
# 31  1.000000  1.000000
# 32  0.571429  0.666667
# 33  1.000000  0.000000
# 34  1.000000  0.666667
# 35  1.000000  1.000000
# 36  1.000000  1.000000
# 37  1.000000  1.000000
# 38  1.000000  1.000000
# 39  1.000000  1.000000
# 40  1.000000  1.000000
